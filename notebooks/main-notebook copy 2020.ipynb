# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
# %pip install understatapi
from understatapi import UnderstatClient

YEAR = '2020'
LEAGUE = 'EPL'

# get data for every player playing in the Premier League in 2019/20

# %%
def process_shot_data(player_shot_data):
    for shot in player_shot_data:
        shot['ScoredEarlier']=0
        shot['ScoredPenEarlier']=0
        shot['ScoredLater']=0
        shot['ScoredPenLater']=0
        shot['PrevAccumXG']=0.0

        # if shot['a_goals']==shot['h_goals']:
        #     shot['State']='tied'
        # elif (shot['a_goals']>shot['h_goals'] and shot['h_a']=='a') or (shot['a_goals']<shot['h_goals'] and shot['h_a']=='h'):
        #     shot['State']='winning'
        # else:
        #     shot['State']='losing'
        # ovo ne radi jer H_GOALS i A_GOALS prikazuju rezultat na kraju, a ne u trenutku suta.
        
        if(shot['result']=='Goal'):
            shot['IsGoal']=True
        else:
            shot['IsGoal']=False


    for i in range(len(player_shot_data)):
        shot = player_shot_data[i]
        original_date = (shot['date'].split()[0])
        if(shot['result']=='Goal'):
            j=i+1
            while  j<len(player_shot_data) and player_shot_data[j]['date'].split()[0] == original_date:
                player_shot_data[j]['ScoredEarlier']=1
                j+=1
            
            
            j=i-1
            while player_shot_data[j]['date'].split()[0] == original_date and j>=0:
                player_shot_data[j]['ScoredLater']=1
                j-=1

    if(len(player_shot_data)==0): return
    prev_date = (player_shot_data[0]['date'].split()[0])
    accum_xG = 0.0 
    for i in range(len(player_shot_data)):
        shot = player_shot_data[i]
        shot['PrevAccumXG']=accum_xG
        accum_xG+=float(shot['xG'])
        if shot['date'].split()[0] != prev_date:
            accum_xG = 0.0
            prev_date = shot['date'].split()[0]

        
        # print(shot['date'].split()[0])
        # print(shot['minute'])

# %%
def prepare_one_dataframe(YEAR, LEAGUE):
    understat = UnderstatClient()
    league_player_ids = set()
    league_player_data = understat.league(league=LEAGUE).get_player_data(season=YEAR)
    league_player_ids.update( [player['id'] for player in league_player_data])

    all_player_shot_data = []
    for player_id in league_player_ids:
        shot_data = understat.player(player=player_id).get_shot_data()
        process_shot_data(shot_data)
        all_player_shot_data+=shot_data





    from heapq import merge


    match_shots = [understat.match(match_info['id']).get_shot_data() for match_info in understat.league(LEAGUE).get_match_data(season = YEAR)]

    all_match_shot_data = []

    for i in range(len(match_shots)):
        team_dic = match_shots[i]
        match=list(merge(team_dic['a'], team_dic['h'], key=lambda shot : int(shot['minute'])))

        home_goals_so_far=0
        away_goals_so_far=0
        for shot in match:
            if shot['h_a']=='h':
                shot['MyScore']=home_goals_so_far
                shot['OppScore']=away_goals_so_far
            else:
                shot['MyScore']=away_goals_so_far
                shot['OppScore']=home_goals_so_far

            if shot['result']=='Goal':
                if shot['h_a']=='h':
                    home_goals_so_far+=1
                else:
                    away_goals_so_far+=1
        match_shots[i]=match
        all_match_shot_data+=match



    matchshotdf = pd.DataFrame(all_match_shot_data).set_index('id')
    matchshotdf.head(10)
    shotdf = pd.DataFrame(all_player_shot_data)
    shotdf['PrevAccumXG'].head(20)
    #shotdf.to_csv(f'../data/shotdf_without_betting_before_processing_{YEAR}_{LEAGUE}.csv')
    shotdf = shotdf[ shotdf['season'] == YEAR ].set_index('id')

    # print(shotdf.head(10),
    # matchshotdf[['MyScore','OppScore']].head(10))
    matchshotdf = matchshotdf[['MyScore','OppScore']]
    #matchshotdf.to_csv(f'../data/scores_{YEAR}_{LEAGUE}.csv')
    shotdf = shotdf.join(matchshotdf, how='inner')

    # shotdf['minute'] = shotdf['minute'].apply(int)
    # shotdf['xG'] = shotdf['xG'].apply(float)

    shotdf = shotdf[['minute', 'xG','h_a','season','h_team','a_team','date','ScoredEarlier','ScoredPenEarlier','ScoredLater','ScoredPenLater','IsGoal','MyScore','OppScore','PrevAccumXG']]

    shotdf.to_csv(f'../data/shotdf_without_betting_{YEAR}_{LEAGUE}.csv')

    #test

    shotdf2 = pd.read_csv(f'../data/shotdf_without_betting_{YEAR}_{LEAGUE}.csv')
    print('starting test:')
    print(shotdf.iloc[1])
    print(shotdf2.iloc[1])
    index1 = shotdf.index
    index2 = shotdf2.index
    print(index1[:10])
    print(index2[:10])
    print(len(index1))
    print(len(index2))
    for elem in shotdf.iloc[1]:
        print(type(elem))
    for elem in shotdf2.iloc[1]:
        print(type(elem))
    print('ending test')

# %%
shotdf=None
try:
    shotdf = pd.read_csv(f'../data/shotdf_without_betting_{YEAR}_{LEAGUE}.csv')
except Exception:
    prepare_one_dataframe(YEAR, LEAGUE)
    shotdf = pd.read_csv(f'../data/shotdf_without_betting_{YEAR}_{LEAGUE}.csv')

# %%
totalxg=shotdf['xG'].sum()
totalgoals=shotdf['IsGoal'].sum()
print(totalgoals / totalxg)
print(len(shotdf[shotdf['ScoredLater']==1]['IsGoal'].index))
print( shotdf[shotdf['ScoredLater']==1]['IsGoal'].sum() / shotdf[ shotdf['ScoredLater'] == 1]['xG'].sum())
# Out:
# 0.9339930436698685
# 825
# 1.0108295109069645

# %%
print(len(shotdf.index))
shotdf = shotdf[shotdf['xG']>0.04]
print(len(shotdf.index))
shotdf['ScaledIsGoal'] = shotdf['IsGoal'] / shotdf['xG']
shotdf['ScaledIsGoal'].head(30)
# Out:
# 9235
# 5766
# 1      0.000000
# 2      0.000000
# 3      0.000000
# 4      0.000000
# 5      0.000000
# 6      0.000000
# 7      0.000000
# 8      1.226054
# 13     0.000000
# 14     0.000000
# 15     0.000000
# 16     0.000000
# 17     0.000000
# 18    17.950744
# 24     0.000000
# 25     0.000000
# 26     0.000000
# 27     9.243340
# 28     1.761649
# 29     3.549510
# 31     0.000000
# 32     0.000000
# 33     0.000000
# 34     0.000000
# 35     0.000000
# 39     0.000000
# 40     0.000000
# 41     0.000000
# 42     0.000000
# 43     0.000000
# Name: ScaledIsGoal, dtype: float64

# %%
shotdf.keys()
# Out:
# Index(['id', 'minute', 'xG', 'h_a', 'season', 'h_team', 'a_team', 'date',
#        'ScoredEarlier', 'ScoredPenEarlier', 'ScoredLater', 'ScoredPenLater',
#        'IsGoal', 'MyScore', 'OppScore', 'PrevAccumXG', 'ScaledIsGoal'],
#       dtype='object')

# %%
shotdf['IsHome'] = (shotdf['h_a']=='h').apply(int)
shotdf['WinProb']=-2.0
shotdf['LoseProb']=-2.0

# %%
import json
betting_nameset = set()
def get_season_betting_data(year, league, no_pages=8, translator=None):
    year = int(year)
    betting_nameset = set()
    jsondata=None
    ctr=0
    for i in range(1,no_pages+1):
        with open(f'../data/betting_{year}_{league}_page_{i}.json') as f:
            jsondata = json.load(f)
        print( jsondata['d']['rows'][0].keys() )

        # print( jsondata['d']['rows'][0]['odds'][2] )
        # print( jsondata['d']['rows'][0]['date-start-timestamp'] )
        if translator is None:
            for row in jsondata['d']['rows']:
                betting_nameset.add(row['home-name'])
            return betting_nameset, None
        else:
            
            for row in jsondata['d']['rows']:
                ctr+=1
                mask_home = (shotdf['season'] == year) & (shotdf['h_team'] == translator[row['home-name']]) & (shotdf['a_team'] == translator[row['away-name']]) & (shotdf['IsHome']==True)
                mask_away = (shotdf['season'] == year) & (shotdf['h_team'] == translator[row['home-name']]) & (shotdf['a_team'] == translator[row['away-name']]) & (shotdf['IsHome']==False)
                print(mask_home.sum(), mask_away.sum())
                #print(mask.max())
                if mask_home.max()==0 and mask_away.max()==0:
                    print('LOSE', year, row['home-name'], row['away-name'])
                shotdf.loc[mask_home, 'WinProb'] = 1. / row['odds'][0]['avgOdds'] 
                shotdf.loc[mask_home, 'LoseProb'] = 1. / row['odds'][2]['avgOdds']
                shotdf.loc[mask_away, 'LoseProb'] = 1. / row['odds'][0]['avgOdds'] 
                shotdf.loc[mask_away, 'WinProb'] = 1. / row['odds'][2]['avgOdds']
            print(f'{ctr=}')


#ovaj deo sluzi samo za nameset! kasnije se zap koristi get_season_betting_data

names, _ = get_season_betting_data(2019, LEAGUE)
print(names)
betting_nameset = betting_nameset.union(names)
names, _ = get_season_betting_data(2020, LEAGUE)
betting_nameset = betting_nameset.union(names)
names, _ = get_season_betting_data(2021, LEAGUE)
betting_nameset = betting_nameset.union(names)
# names, _ = get_season_betting_data(2022, LEAGUE)
# betting_nameset = betting_nameset.union(names)
# Out:
# dict_keys(['id', 'is-double', 'superTemplate', 'home', 'away', 'home-name', 'away-name', 'home-country-two-chart-name', 'away-country-two-chart-name', 'home-participant-id', 'away-participant-id', 'status-id', 'event-stage-id', 'event-stage-name', 'event-stage-name-short', 'tournament_id', 'tournament-stage-id', 'tournament-stage-type-id', 'tournament-stage-group-id', 'tournament-stage-name', 'sport-id', 'cols', 'home-participant-images', 'away-participant-images', 'encodeEventId', 'colClassName', 'homeParticipantTypes', 'awayParticipantTypes', 'ftOnly', 'ftOnlyText', 'ftOnlyTextShort', 'url', 'date-start-base', 'date-start-timestamp', 'result', 'homeResult', 'awayResult', 'homeTextInResult', 'awayTextInResult', 'home-winner', 'away-winner', 'postmatchResult', 'info', 'partialresult', 'country-id', 'country-name', 'country-two-chart-name', 'country-type', 'tournament-id', 'tournament-name', 'tournament-url', 'sport-url-name', 'breadcrumbs', 'stream', 'bookmakersCount', 'winner_post', 'betting_type', 'odds', 'name', 'colClassNameTime'])
# {'Aston Villa', 'Sheffield Utd', 'Liverpool', 'Crystal Palace', 'West Ham', 'Southampton', 'Leicester', 'Manchester City', 'Burnley', 'Tottenham', 'Manchester Utd', 'Arsenal', 'Chelsea', 'Newcastle', 'Wolves', 'Norwich', 'Brighton', 'Watford', 'Bournemouth', 'Everton'}
# dict_keys(['id', 'is-double', 'superTemplate', 'home', 'away', 'home-name', 'away-name', 'home-country-two-chart-name', 'away-country-two-chart-name', 'home-participant-id', 'away-participant-id', 'status-id', 'event-stage-id', 'event-stage-name', 'event-stage-name-short', 'tournament_id', 'tournament-stage-id', 'tournament-stage-type-id', 'tournament-stage-group-id', 'tournament-stage-name', 'sport-id', 'cols', 'home-participant-images', 'away-participant-images', 'encodeEventId', 'colClassName', 'homeParticipantTypes', 'awayParticipantTypes', 'ftOnly', 'ftOnlyText', 'ftOnlyTextShort', 'url', 'date-start-base', 'date-start-timestamp', 'result', 'homeResult', 'awayResult', 'homeTextInResult', 'awayTextInResult', 'home-winner', 'away-winner', 'postmatchResult', 'info', 'partialresult', 'country-id', 'country-name', 'country-two-chart-name', 'country-type', 'tournament-id', 'tournament-name', 'tournament-url', 'sport-url-name', 'breadcrumbs', 'stream', 'bookmakersCount', 'winner_post', 'betting_type', 'odds', 'name', 'colClassNameTime'])
# dict_keys(['id', 'is-double', 'superTemplate', 'home', 'away', 'home-name', 'away-name', 'home-country-two-chart-name', 'away-country-two-chart-name', 'home-participant-id', 'away-participant-id', 'status-id', 'event-stage-id', 'event-stage-name', 'event-stage-name-short', 'tournament_id', 'tournament-stage-id', 'tournament-stage-type-id', 'tournament-stage-group-id', 'tournament-stage-name', 'sport-id', 'cols', 'home-participant-images', 'away-participant-images', 'encodeEventId', 'colClassName', 'homeParticipantTypes', 'awayParticipantTypes', 'ftOnly', 'ftOnlyText', 'ftOnlyTextShort', 'url', 'date-start-base', 'date-start-timestamp', 'result', 'homeResult', 'awayResult', 'homeTextInResult', 'awayTextInResult', 'home-winner', 'away-winner', 'postmatchResult', 'info', 'partialresult', 'country-id', 'country-name', 'country-two-chart-name', 'country-type', 'tournament-id', 'tournament-name', 'tournament-url', 'sport-url-name', 'breadcrumbs', 'stream', 'bookmakersCount', 'winner_post', 'betting_type', 'odds', 'name', 'colClassNameTime'])

# %%
understat_nameset = set()
shotdf.apply(axis = 1, func = lambda row : understat_nameset.add(row['h_team']))
print(understat_nameset)

beting_iter = iter(betting_nameset)
# Out:
# {'Leeds', 'Aston Villa', 'Liverpool', 'Crystal Palace', 'West Ham', 'Southampton', 'Wolverhampton Wanderers', 'West Bromwich Albion', 'Leicester', 'Sheffield United', 'Manchester City', 'Burnley', 'Tottenham', 'Manchester United', 'Fulham', 'Arsenal', 'Chelsea', 'Newcastle United', 'Brighton', 'Everton'}

# %%
name_translator = {}
l_betting_nameset = list(betting_nameset)
for name in l_betting_nameset:
    if name in understat_nameset:
        name_translator[name]=name
        understat_nameset.remove(name)
        betting_nameset.remove(name)
print(betting_nameset)
name_translator['Manchester Utd'] = 'Manchester United'
name_translator['Wolves'] = 'Wolverhampton Wanderers'
name_translator['Newcastle'] = 'Newcastle United'
name_translator['Sheffield Utd'] = 'Sheffield United'
name_translator['Nottingham'] = 'Nottingham Forest'
name_translator['Brentford'] = 'Brentford'
name_translator['Fulham'] = 'Fulham'
name_translator['Leeds'] = 'Leeds'
name_translator['West Brom'] = 'West Bromwich Albion'
# Out:
# {'Sheffield Utd', 'Brentford', 'West Brom', 'Manchester Utd', 'Newcastle', 'Wolves', 'Norwich', 'Watford', 'Bournemouth'}

# %%
print(YEAR)
print(type(YEAR))
# Out:
# 2020
# <class 'str'>

# %%
betting_data = get_season_betting_data(YEAR, LEAGUE, 8, name_translator)
# Out:
# dict_keys(['id', 'is-double', 'superTemplate', 'home', 'away', 'home-name', 'away-name', 'home-country-two-chart-name', 'away-country-two-chart-name', 'home-participant-id', 'away-participant-id', 'status-id', 'event-stage-id', 'event-stage-name', 'event-stage-name-short', 'tournament_id', 'tournament-stage-id', 'tournament-stage-type-id', 'tournament-stage-group-id', 'tournament-stage-name', 'sport-id', 'cols', 'home-participant-images', 'away-participant-images', 'encodeEventId', 'colClassName', 'homeParticipantTypes', 'awayParticipantTypes', 'ftOnly', 'ftOnlyText', 'ftOnlyTextShort', 'url', 'date-start-base', 'date-start-timestamp', 'result', 'homeResult', 'awayResult', 'homeTextInResult', 'awayTextInResult', 'home-winner', 'away-winner', 'postmatchResult', 'info', 'partialresult', 'country-id', 'country-name', 'country-two-chart-name', 'country-type', 'tournament-id', 'tournament-name', 'tournament-url', 'sport-url-name', 'breadcrumbs', 'stream', 'bookmakersCount', 'winner_post', 'betting_type', 'odds', 'name', 'colClassNameTime'])
# 7 2
# 4 12
# 7 6
# 9 11
# 5 7
# 12 4
# 17 5
# 5 6
# 12 10
# 8 5
# 6 13
# 6 10
# 7 4
# 6 2
# 8 5
# 8 12
# 14 4
# 11 7
# 7 4
# 7 8
# 7 4
# 5 13
# 16 10
# 13 11
# 5 7
# 11 7
# 10 10
# 10 9
# 10 14
# 8 13
# 11 3
# 12 7
# 3 5
# 7 10
# 9 8
# 6 9
# 6 9
# 9 2
# 13 6
# 9 7
# 4 13
# 12 6
# 16 10
# 7 15
# 5 10
# 11 4
# 2 13
# 8 7
# 7 3
# 13 6
# ctr=50
# dict_keys(['id', 'is-double', 'superTemplate', 'home', 'away', 'home-name', 'away-name', 'home-country-two-chart-name', 'away-country-two-chart-name', 'home-participant-id', 'away-participant-id', 'status-id', 'event-stage-id', 'event-stage-name', 'event-stage-name-short', 'tournament_id', 'tournament-stage-id', 'tournament-stage-type-id', 'tournament-stage-group-id', 'tournament-stage-name', 'sport-id', 'cols', 'home-participant-images', 'away-participant-images', 'encodeEventId', 'colClassName', 'homeParticipantTypes', 'awayParticipantTypes', 'ftOnly', 'ftOnlyText', 'ftOnlyTextShort', 'url', 'date-start-base', 'date-start-timestamp', 'result', 'homeResult', 'awayResult', 'homeTextInResult', 'awayTextInResult', 'home-winner', 'away-winner', 'postmatchResult', 'info', 'partialresult', 'country-id', 'country-name', 'country-two-chart-name', 'country-type', 'tournament-id', 'tournament-name', 'tournament-url', 'sport-url-name', 'breadcrumbs', 'stream', 'bookmakersCount', 'betting_type', 'winner_post', 'odds', 'name', 'colClassNameTime'])
# 3 17
# 3 9
# 9 4
# 12 6
# 2 12
# 4 6
# 4 9
# 2 9
# 15 4
# 9 6
# 13 2
# 7 7
# 7 5
# 5 5
# 9 10
# 10 4
# 11 2
# 8 4
# 11 8
# 12 7
# 15 3
# 14 8
# 3 10
# 8 8
# 4 11
# 14 7
# 1 20
# 18 5
# 16 2
# 4 5
# 13 8
# 13 8
# 8 5
# 6 7
# 15 9
# 12 5
# 1 9
# 2 10
# 16 3
# 14 9
# 5 6
# 11 10
# 6 1
# 9 9
# 6 9
# 9 6
# 6 3
# 15 1
# 6 4
# 2 6
# ctr=100
# dict_keys(['id', 'is-double', 'superTemplate', 'home', 'away', 'home-name', 'away-name', 'home-country-two-chart-name', 'away-country-two-chart-name', 'home-participant-id', 'away-participant-id', 'status-id', 'event-stage-id', 'event-stage-name', 'event-stage-name-short', 'tournament_id', 'tournament-stage-id', 'tournament-stage-type-id', 'tournament-stage-group-id', 'tournament-stage-name', 'sport-id', 'cols', 'home-participant-images', 'away-participant-images', 'encodeEventId', 'colClassName', 'homeParticipantTypes', 'awayParticipantTypes', 'ftOnly', 'ftOnlyText', 'ftOnlyTextShort', 'url', 'date-start-base', 'date-start-timestamp', 'result', 'homeResult', 'awayResult', 'homeTextInResult', 'awayTextInResult', 'home-winner', 'away-winner', 'postmatchResult', 'info', 'partialresult', 'country-id', 'country-name', 'country-two-chart-name', 'country-type', 'tournament-id', 'tournament-name', 'tournament-url', 'sport-url-name', 'breadcrumbs', 'stream', 'bookmakersCount', 'betting_type', 'winner_post', 'odds', 'name', 'colClassNameTime'])
# 7 9
# 4 7
# 5 10
# 6 5
# 14 8
# 9 10
# 8 2
# 9 4
# 12 7
# 7 10
# 7 5
# 6 5
# 6 6
# 4 10
# 6 12
# 1 8
# 6 5
# 8 6
# 6 5
# 6 8
# 6 11
# 16 4
# 6 4
# 4 13
# 6 3
# 12 5
# 1 8
# 4 7
# 13 4
# 6 6
# 3 12
# 6 5
# 11 6
# 19 1
# 9 4
# 5 13
# 7 10
# 3 11
# 4 3
# 7 5
# 3 5
# 4 6
# 6 12
# 3 11
# 6 4
# 10 7
# 11 3
# 3 7
# 9 5
# 5 5
# ctr=150
# dict_keys(['id', 'is-double', 'superTemplate', 'home', 'away', 'home-name', 'away-name', 'home-country-two-chart-name', 'away-country-two-chart-name', 'home-participant-id', 'away-participant-id', 'status-id', 'event-stage-id', 'event-stage-name', 'event-stage-name-short', 'tournament_id', 'tournament-stage-id', 'tournament-stage-type-id', 'tournament-stage-group-id', 'tournament-stage-name', 'sport-id', 'cols', 'home-participant-images', 'away-participant-images', 'encodeEventId', 'colClassName', 'homeParticipantTypes', 'awayParticipantTypes', 'ftOnly', 'ftOnlyText', 'ftOnlyTextShort', 'url', 'date-start-base', 'date-start-timestamp', 'result', 'homeResult', 'awayResult', 'homeTextInResult', 'awayTextInResult', 'home-winner', 'away-winner', 'postmatchResult', 'info', 'partialresult', 'country-id', 'country-name', 'country-two-chart-name', 'country-type', 'tournament-id', 'tournament-name', 'tournament-url', 'sport-url-name', 'breadcrumbs', 'stream', 'bookmakersCount', 'betting_type', 'winner_post', 'odds', 'name', 'colClassNameTime'])
# 5 2
# 17 1
# 12 5
# 7 9
# 9 10
# 12 4
# 3 6
# 6 6
# 8 6
# 9 4
# 9 5
# 13 4
# 13 8
# 6 11
# 8 8
# 4 12
# 7 12
# 6 8
# 10 7
# 1 13
# 4 6
# 18 2
# 13 3
# 10 5
# 6 5
# 13 4
# 5 8
# 6 6
# 13 1
# 12 6
# 10 6
# 7 3
# 6 2
# 3 9
# 7 9
# 1 10
# 5 8
# 10 5
# 11 6
# 4 16
# 6 3
# 9 8
# 4 12
# 3 16
# 8 8
# 8 3
# 15 5
# 6 10
# 21 6
# 4 7
# ctr=200
# dict_keys(['id', 'is-double', 'superTemplate', 'home', 'away', 'home-name', 'away-name', 'home-country-two-chart-name', 'away-country-two-chart-name', 'home-participant-id', 'away-participant-id', 'status-id', 'event-stage-id', 'event-stage-name', 'event-stage-name-short', 'tournament_id', 'tournament-stage-id', 'tournament-stage-type-id', 'tournament-stage-group-id', 'tournament-stage-name', 'sport-id', 'cols', 'home-participant-images', 'away-participant-images', 'encodeEventId', 'colClassName', 'homeParticipantTypes', 'awayParticipantTypes', 'ftOnly', 'ftOnlyText', 'ftOnlyTextShort', 'url', 'date-start-base', 'date-start-timestamp', 'result', 'homeResult', 'awayResult', 'homeTextInResult', 'awayTextInResult', 'home-winner', 'away-winner', 'postmatchResult', 'info', 'partialresult', 'country-id', 'country-name', 'country-two-chart-name', 'country-type', 'tournament-id', 'tournament-name', 'tournament-url', 'sport-url-name', 'breadcrumbs', 'stream', 'bookmakersCount', 'winner_post', 'betting_type', 'odds', 'name', 'colClassNameTime'])
# 8 3
# 16 1
# 8 1
# 9 6
# 4 8
# 13 5
# 5 10
# 3 5
# 13 4
# 13 10
# 5 8
# 12 9
# 14 1
# 5 9
# 8 3
# 14 5
# 4 9
# 5 17
# 3 6
# 2 16
# 8 6
# 6 4
# 16 9
# 12 10
# 4 8
# 5 6
# 8 5
# 8 9
# 5 3
# 4 7
# 1 10
# 11 6
# 4 11
# 6 5
# 9 3
# 7 9
# 8 7
# 10 2
# 5 4
# 14 12
# 18 6
# 8 2
# 6 8
# 8 5
# 8 9
# 0 11
# 17 11
# 6 11
# 11 4
# 6 7
# ctr=250
# dict_keys(['id', 'is-double', 'superTemplate', 'home', 'away', 'home-name', 'away-name', 'home-country-two-chart-name', 'away-country-two-chart-name', 'home-participant-id', 'away-participant-id', 'status-id', 'event-stage-id', 'event-stage-name', 'event-stage-name-short', 'tournament_id', 'tournament-stage-id', 'tournament-stage-type-id', 'tournament-stage-group-id', 'tournament-stage-name', 'sport-id', 'cols', 'home-participant-images', 'away-participant-images', 'encodeEventId', 'colClassName', 'homeParticipantTypes', 'awayParticipantTypes', 'ftOnly', 'ftOnlyText', 'ftOnlyTextShort', 'url', 'date-start-base', 'date-start-timestamp', 'result', 'homeResult', 'awayResult', 'homeTextInResult', 'awayTextInResult', 'home-winner', 'away-winner', 'postmatchResult', 'info', 'partialresult', 'country-id', 'country-name', 'country-two-chart-name', 'country-type', 'tournament-id', 'tournament-name', 'tournament-url', 'sport-url-name', 'breadcrumbs', 'stream', 'bookmakersCount', 'winner_post', 'betting_type', 'odds', 'name', 'colClassNameTime'])
# 5 9
# 5 6
# 3 12
# 8 9
# 18 5
# 4 5
# 12 5
# 4 6
# 3 4
# 18 7
# 5 7
# 13 2
# 4 7
# 12 7
# 12 5
# 7 8
# 11 6
# 11 3
# 7 7
# 9 7
# 7 7
# 12 8
# 8 12
# 10 4
# 10 5
# 4 8
# 3 9
# 5 13
# 19 6
# 10 9
# 14 3
# 4 8
# 4 10
# 10 7
# 8 10
# 9 3
# 6 10
# 10 15
# 8 17
# 15 3
# 9 2
# 6 9
# 13 6
# 7 6
# 19 8
# 16 6
# 5 12
# 5 8
# 8 5
# 4 14
# ctr=300
# dict_keys(['id', 'is-double', 'superTemplate', 'home', 'away', 'home-name', 'away-name', 'home-country-two-chart-name', 'away-country-two-chart-name', 'home-participant-id', 'away-participant-id', 'status-id', 'event-stage-id', 'event-stage-name', 'event-stage-name-short', 'tournament_id', 'tournament-stage-id', 'tournament-stage-type-id', 'tournament-stage-group-id', 'tournament-stage-name', 'sport-id', 'cols', 'home-participant-images', 'away-participant-images', 'encodeEventId', 'colClassName', 'homeParticipantTypes', 'awayParticipantTypes', 'ftOnly', 'ftOnlyText', 'ftOnlyTextShort', 'url', 'date-start-base', 'date-start-timestamp', 'result', 'homeResult', 'awayResult', 'homeTextInResult', 'awayTextInResult', 'home-winner', 'away-winner', 'postmatchResult', 'info', 'partialresult', 'country-id', 'country-name', 'country-two-chart-name', 'country-type', 'tournament-id', 'tournament-name', 'tournament-url', 'sport-url-name', 'breadcrumbs', 'stream', 'bookmakersCount', 'betting_type', 'winner_post', 'odds', 'name', 'colClassNameTime'])
# 5 7
# 4 10
# 9 13
# 3 6
# 6 3
# 6 8
# 9 8
# 16 4
# 8 6
# 5 7
# 10 2
# 11 3
# 6 9
# 7 8
# 7 4
# 3 4
# 8 9
# 14 8
# 7 3
# 1 8
# 4 12
# 8 5
# 7 5
# 3 2
# 9 3
# 7 3
# 9 3
# 8 9
# 7 2
# 10 13
# 2 6
# 8 20
# 8 3
# 7 5
# 7 6
# 8 10
# 1 13
# 6 5
# 4 15
# 9 7
# 9 5
# 6 19
# 13 10
# 2 17
# 5 2
# 7 8
# 3 11
# 8 2
# 5 4
# 11 15
# ctr=350
# dict_keys(['id', 'is-double', 'superTemplate', 'home', 'away', 'home-name', 'away-name', 'home-country-two-chart-name', 'away-country-two-chart-name', 'home-participant-id', 'away-participant-id', 'status-id', 'event-stage-id', 'event-stage-name', 'event-stage-name-short', 'tournament_id', 'tournament-stage-id', 'tournament-stage-type-id', 'tournament-stage-group-id', 'tournament-stage-name', 'sport-id', 'cols', 'home-participant-images', 'away-participant-images', 'encodeEventId', 'colClassName', 'homeParticipantTypes', 'awayParticipantTypes', 'ftOnly', 'ftOnlyText', 'ftOnlyTextShort', 'url', 'date-start-base', 'date-start-timestamp', 'result', 'homeResult', 'awayResult', 'homeTextInResult', 'awayTextInResult', 'home-winner', 'away-winner', 'postmatchResult', 'info', 'partialresult', 'country-id', 'country-name', 'country-two-chart-name', 'country-type', 'tournament-id', 'tournament-name', 'tournament-url', 'sport-url-name', 'breadcrumbs', 'stream', 'bookmakersCount', 'winner_post', 'betting_type', 'odds', 'name', 'colClassNameTime'])
# 7 7
# 11 1
# 13 4
# 5 10
# 12 5
# 9 5
# 17 3
# 10 11
# 5 4
# 6 13
# 4 8
# 12 6
# 6 10
# 8 2
# 11 12
# 2 12
# 2 7
# 9 8
# 7 10
# 5 11
# 9 8
# 14 5
# 7 6
# 5 8
# 5 10
# 3 11
# 8 8
# 17 3
# 5 8
# 1 12
# ctr=380

# %%
print(name_translator)
# Out:
# {'Leeds': 'Leeds', 'Aston Villa': 'Aston Villa', 'Liverpool': 'Liverpool', 'Crystal Palace': 'Crystal Palace', 'West Ham': 'West Ham', 'Southampton': 'Southampton', 'Leicester': 'Leicester', 'Manchester City': 'Manchester City', 'Burnley': 'Burnley', 'Tottenham': 'Tottenham', 'Fulham': 'Fulham', 'Arsenal': 'Arsenal', 'Chelsea': 'Chelsea', 'Brighton': 'Brighton', 'Everton': 'Everton', 'Manchester Utd': 'Manchester United', 'Wolves': 'Wolverhampton Wanderers', 'Newcastle': 'Newcastle United', 'Sheffield Utd': 'Sheffield United', 'Nottingham': 'Nottingham Forest', 'Brentford': 'Brentford', 'West Brom': 'West Bromwich Albion'}

# %%
print(len(shotdf[shotdf['WinProb']!=-2].index))
# print(shotdf[['season','HomeOdds']])
print(shotdf.iloc[0])
# Out:
# 5766
# id                               376627
# minute                               86
# xG                             0.104761
# h_a                                   h
# season                             2020
# h_team                        Liverpool
# a_team                            Leeds
# date                2020-09-12 16:30:00
# ScoredEarlier                         0
# ScoredPenEarlier                      0
# ScoredLater                           0
# ScoredPenLater                        0
# IsGoal                            False
# MyScore                               3
# OppScore                              3
# PrevAccumXG                         0.0
# ScaledIsGoal                        0.0
# IsHome                                1
# WinProb                        0.787402
# LoseProb                       0.091408
# Name: 1, dtype: object

# %%
# %pip install scikit-learn
from sklearn.linear_model import LinearRegression

#shotdf[shotdf['h_a']=='h']['IsHome'] = 1
X = shotdf[['minute','IsHome','ScoredEarlier','MyScore','OppScore','WinProb','LoseProb','PrevAccumXG']]
y = shotdf['ScaledIsGoal']


model = LinearRegression()
model.fit(X, y)
model_numbers = (list(model.coef_) + [model.intercept_])
plt.plot(model_numbers)

first_shot = (shotdf.iloc[[0]][['minute','IsHome','ScoredEarlier','MyScore','OppScore','WinProb','LoseProb','PrevAccumXG']] )
print(first_shot)
print(model.predict( first_shot))
# Out:
#    minute  IsHome  ScoredEarlier  MyScore  OppScore   WinProb  LoseProb  \
# 1      86       1              0        3         3  0.787402  0.091408
#
#    PrevAccumXG
# 1          0.0
# [1.10346106]

# %%
aware_coefficient = model.predict(shotdf[['minute','IsHome','ScoredEarlier','MyScore','OppScore','WinProb','LoseProb','PrevAccumXG']])
shotdf['AwareXG'] = shotdf['xG']*aware_coefficient
shotdf[['xG','AwareXG']].head(20)

plt.plot(sorted(aware_coefficient))

# %% [markdown]
# # Zastareo kod

# %%
raise Exception
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 raise Exception
#
# Exception:

# %%
xg_if_scored_earlier = 0
xg_if_scored_later = 0
total_xg = 0
scored_if_scored_earlier = 0
scored_if_scored_later = 0
total_shots = len(all_player_shot_data)
total_goals = 0
for shot in all_player_shot_data:
    if shot['IsGoal']:
        total_goals+=1
        if shot['ScoredEarlier']==1:
            scored_if_scored_earlier+=1
        if shot['ScoredLater']==1:
            scored_if_scored_later+=1
    if shot['ScoredEarlier']==1:
        xg_if_scored_earlier+=float(shot['xG'])
    if shot['ScoredLater']==1:
        xg_if_scored_later+=float(shot['xG'])
    total_xg += float(shot['xG'])

print(scored_if_scored_earlier, scored_if_scored_later)
print(xg_if_scored_earlier, xg_if_scored_later)
ratio_if_scored_earlier = scored_if_scored_earlier / xg_if_scored_earlier
ratio_if_scored_later = scored_if_scored_later / xg_if_scored_later
ratio_total = total_goals / total_xg
print(f'{ratio_if_scored_earlier=} {ratio_if_scored_later=} {ratio_total=}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 6
#       4 scored_if_scored_earlier = 0
#       5 scored_if_scored_later = 0
# ----> 6 total_shots = len(all_player_shot_data)
#       7 total_goals = 0
#       8 for shot in all_player_shot_data:
#
# NameError: name 'all_player_shot_data' is not defined

# %%
# print([ lis['id'] for lis in (match_dic[('2015-02-07 15:00:00', 'Leicester', 'Crystal Palace')]) ])
# print([ lis['id'] for lis in (match_dic[('2014-10-04 15:00:00', 'Leicester', 'Burnley')]) ] )

# 'h_team': 'Leicester', 'a_team': 'Burnley', 'h_goals': '2', 'a_goals': '2', 'date': '2014-10-04 15:00:00'

# %%
from functools import reduce
def get_xg_and_goals_for_condition_combination(shot_data, condition_dic):
    keys = list(condition_dic.keys())
    vals = list(condition_dic.values())

    conditional_xg = 0
    conditional_goals = 0

    for shot in shot_data:
        # if len(args)==0 or reduce((lambda x, y: x and y), [shot[arg] for arg in args]):
        if vals == [shot[arg] for arg in keys]:
            conditional_xg += float(shot['xG'])
            conditional_goals += int(shot['IsGoal'])
    return conditional_xg, conditional_goals
print(get_xg_and_goals_for_condition_combination(all_player_shot_data, {'ScoredEarlier': True}) )

# 'State' nije dobar. otkomentarisi ovo kad iskoristis match data da 

# print(get_xg_and_goals_for_condition_combination(all_player_shot_data, {'ScoredEarlier': True ,'State': 'winning'}))
# print(get_xg_and_goals_for_condition_combination(all_player_shot_data, {'ScoredEarlier': True ,'State': 'tied'}))
# print(get_xg_and_goals_for_condition_combination(all_player_shot_data, {'ScoredEarlier': True ,'State': 'losing'}))
# print(get_xg_and_goals_for_condition_combination(all_player_shot_data, {'State': 'winning'}))
# print(get_xg_and_goals_for_condition_combination(all_player_shot_data, {'State': 'tied'}))
# print(get_xg_and_goals_for_condition_combination(all_player_shot_data, {'State': 'losing'}))
# Out:
# (1016.7205622913316, 931)

# %%
[1,2]==[True,2]
# Out:
# True

# %%
print(all_player_shot_data[0])
# Out:
# {'id': '52025', 'minute': '3', 'result': 'BlockedShot', 'X': '0.7830000305175782', 'Y': '0.5209999847412109', 'xG': '0.051129300147295', 'player': 'Tom Davies', 'h_a': 'h', 'player_id': '1042', 'situation': 'OpenPlay', 'season': '2015', 'shotType': 'RightFoot', 'match_id': '453', 'h_team': 'Everton', 'a_team': 'Norwich', 'h_goals': '3', 'a_goals': '0', 'date': '2016-05-15 18:00:00', 'player_assisted': 'Kieran Dowell', 'lastAction': 'LayOff', 'ScoredEarlier': 0, 'ScoredPenEarlier': 0, 'ScoredLater': 0, 'ScoredPenLater': 0, 'IsGoal': False}

# %% [markdown]
# # Treba da se odradi game state, znaci da li je u trenutku suta taj tim gubio, pobedjivao ili su bili izjednaceni.
# Treba u recniku match_data napraviti hronoloski sortiranu listu suteva (koristeci id) koji su ispali golovi.  onda kad se to zavrsi da se vratimo u shot data i da napravimo jos jednu kolonu / key. ovo ovako mora zato sto je shot data prvenstveno sortiran po igracu pa tek onda po vremenu. Treba koristiti match_id i shot_id sto vise, i cinjenicu da je 0-10 puta u istoriji (jako retko lupam brojeve) dato vise golova u istom minutu (sto je dovoljno da ne utice na podatke)

# %%
understat.match('22009').get_shot_data()
# Out:
# {'h': [{'id': '549079',
#    'minute': '0',
#    'result': 'BlockedShot',
#    'X': '0.8590000152587891',
#    'Y': '0.2879999923706055',
#    'xG': '0.038173574954271317',
#    'player': 'Reece James',
#    'h_a': 'h',
#    'player_id': '8067',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': 'Cole Palmer',
#    'lastAction': 'BallTouch'},
#   {'id': '549080',
#    'minute': '11',
#    'result': 'BlockedShot',
#    'X': '0.8909999847412109',
#    'Y': '0.3129999923706055',
#    'xG': '0.04885943979024887',
#    'player': 'Cole Palmer',
#    'h_a': 'h',
#    'player_id': '8497',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'LeftFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': 'Reece James',
#    'lastAction': 'Pass'},
#   {'id': '549083',
#    'minute': '18',
#    'result': 'SavedShot',
#    'X': '0.7769999694824219',
#    'Y': '0.4420000076293945',
#    'xG': '0.02994546853005886',
#    'player': 'Conor Gallagher',
#    'h_a': 'h',
#    'player_id': '9040',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '549085',
#    'minute': '26',
#    'result': 'BlockedShot',
#    'X': '0.7780000305175782',
#    'Y': '0.5329999923706055',
#    'xG': '0.031317587941884995',
#    'player': 'Moisés Caicedo',
#    'h_a': 'h',
#    'player_id': '9453',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': 'Conor Gallagher',
#    'lastAction': 'Pass'},
#   {'id': '549086',
#    'minute': '27',
#    'result': 'SavedShot',
#    'X': '0.7819999694824219',
#    'Y': '0.6430000305175781',
#    'xG': '0.07217331975698471',
#    'player': 'Reece James',
#    'h_a': 'h',
#    'player_id': '8067',
#    'situation': 'DirectFreekick',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '549087',
#    'minute': '28',
#    'result': 'Goal',
#    'X': '0.9519999694824218',
#    'Y': '0.39099998474121095',
#    'xG': '0.03896832466125488',
#    'player': 'Thiago Silva',
#    'h_a': 'h',
#    'player_id': '3288',
#    'situation': 'FromCorner',
#    'season': '2023',
#    'shotType': 'Head',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': 'Conor Gallagher',
#    'lastAction': 'Cross'},
#   {'id': '549090',
#    'minute': '36',
#    'result': 'Goal',
#    'X': '0.9690000152587891',
#    'Y': '0.504000015258789',
#    'xG': '0.899151623249054',
#    'player': 'Raheem Sterling',
#    'h_a': 'h',
#    'player_id': '618',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': 'Reece James',
#    'lastAction': 'Pass'},
#   {'id': '549091',
#    'minute': '39',
#    'result': 'BlockedShot',
#    'X': '0.785',
#    'Y': '0.6320000076293946',
#    'xG': '0.03905467689037323',
#    'player': 'Enzo Fernández',
#    'h_a': 'h',
#    'player_id': '11356',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'LeftFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '549092',
#    'minute': '40',
#    'result': 'MissedShots',
#    'X': '0.8830000305175781',
#    'Y': '0.6930000305175781',
#    'xG': '0.065186507999897',
#    'player': 'Raheem Sterling',
#    'h_a': 'h',
#    'player_id': '618',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': 'Marc Cucurella',
#    'lastAction': 'Pass'},
#   {'id': '549095',
#    'minute': '43',
#    'result': 'SavedShot',
#    'X': '0.8469999694824218',
#    'Y': '0.5279999923706055',
#    'xG': '0.09315626323223114',
#    'player': 'Nicolas Jackson',
#    'h_a': 'h',
#    'player_id': '10048',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'LeftFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': 'Raheem Sterling',
#    'lastAction': 'BallTouch'},
#   {'id': '549097',
#    'minute': '51',
#    'result': 'BlockedShot',
#    'X': '0.899000015258789',
#    'Y': '0.6630000305175782',
#    'xG': '0.060310084372758865',
#    'player': 'Nicolas Jackson',
#    'h_a': 'h',
#    'player_id': '10048',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'LeftFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '549101',
#    'minute': '59',
#    'result': 'SavedShot',
#    'X': '0.8690000152587891',
#    'Y': '0.5220000076293946',
#    'xG': '0.4637688100337982',
#    'player': 'Cole Palmer',
#    'h_a': 'h',
#    'player_id': '8497',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'LeftFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': 'Moisés Caicedo',
#    'lastAction': 'TakeOn'},
#   {'id': '549103',
#    'minute': '66',
#    'result': 'SavedShot',
#    'X': '0.73',
#    'Y': '0.5329999923706055',
#    'xG': '0.019445979967713356',
#    'player': 'Conor Gallagher',
#    'h_a': 'h',
#    'player_id': '9040',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': 'Moisés Caicedo',
#    'lastAction': 'Pass'},
#   {'id': '549104',
#    'minute': '66',
#    'result': 'Goal',
#    'X': '0.9009999847412109',
#    'Y': '0.47400001525878904',
#    'xG': '0.4349559545516968',
#    'player': 'Nicolas Jackson',
#    'h_a': 'h',
#    'player_id': '10048',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': None,
#    'lastAction': 'Rebound'},
#   {'id': '549105',
#    'minute': '74',
#    'result': 'MissedShots',
#    'X': '0.899000015258789',
#    'Y': '0.40900001525878904',
#    'xG': '0.37120410799980164',
#    'player': 'Malo Gusto',
#    'h_a': 'h',
#    'player_id': '9017',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'LeftFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '549106',
#    'minute': '80',
#    'result': 'MissedShots',
#    'X': '0.71',
#    'Y': '0.47900001525878905',
#    'xG': '0.013997855596244335',
#    'player': 'Conor Gallagher',
#    'h_a': 'h',
#    'player_id': '9040',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': None,
#    'lastAction': 'BallTouch'},
#   {'id': '549109',
#    'minute': '94',
#    'result': 'Goal',
#    'X': '0.885',
#    'Y': '0.5',
#    'xG': '0.7611688375473022',
#    'player': 'Cole Palmer',
#    'h_a': 'h',
#    'player_id': '8497',
#    'situation': 'Penalty',
#    'season': '2023',
#    'shotType': 'LeftFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'}],
#  'a': [{'id': '549081',
#    'minute': '15',
#    'result': 'BlockedShot',
#    'X': '0.9380000305175781',
#    'Y': '0.2979999923706055',
#    'xG': '0.05725177004933357',
#    'player': 'Julián Álvarez',
#    'h_a': 'a',
#    'player_id': '10846',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': 'Rodri',
#    'lastAction': 'Pass'},
#   {'id': '549082',
#    'minute': '16',
#    'result': 'SavedShot',
#    'X': '0.8669999694824219',
#    'Y': '0.5779999923706055',
#    'xG': '0.014905241318047047',
#    'player': 'Josko Gvardiol',
#    'h_a': 'a',
#    'player_id': '9790',
#    'situation': 'FromCorner',
#    'season': '2023',
#    'shotType': 'Head',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': 'Julián Álvarez',
#    'lastAction': 'Cross'},
#   {'id': '549084',
#    'minute': '24',
#    'result': 'Goal',
#    'X': '0.885',
#    'Y': '0.5',
#    'xG': '0.7611688375473022',
#    'player': 'Erling Haaland',
#    'h_a': 'a',
#    'player_id': '8260',
#    'situation': 'Penalty',
#    'season': '2023',
#    'shotType': 'LeftFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '549088',
#    'minute': '31',
#    'result': 'MissedShots',
#    'X': '0.9919999694824219',
#    'Y': '0.5840000152587891',
#    'xG': '0.2866228520870209',
#    'player': 'Erling Haaland',
#    'h_a': 'a',
#    'player_id': '8260',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'LeftFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': 'Phil Foden',
#    'lastAction': 'Cross'},
#   {'id': '549089',
#    'minute': '33',
#    'result': 'MissedShots',
#    'X': '0.855999984741211',
#    'Y': '0.3609999847412109',
#    'xG': '0.06621630489826202',
#    'player': 'Phil Foden',
#    'h_a': 'a',
#    'player_id': '6055',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'LeftFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': 'Rodri',
#    'lastAction': 'Pass'},
#   {'id': '549093',
#    'minute': '41',
#    'result': 'SavedShot',
#    'X': '0.874000015258789',
#    'Y': '0.5579999923706055',
#    'xG': '0.3491571247577667',
#    'player': 'Erling Haaland',
#    'h_a': 'a',
#    'player_id': '8260',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'LeftFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': 'Bernardo Silva',
#    'lastAction': 'Pass'},
#   {'id': '549094',
#    'minute': '42',
#    'result': 'SavedShot',
#    'X': '0.7809999847412109',
#    'Y': '0.33099998474121095',
#    'xG': '0.024481579661369324',
#    'player': 'Phil Foden',
#    'h_a': 'a',
#    'player_id': '6055',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'LeftFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': 'Kyle Walker',
#    'lastAction': 'Pass'},
#   {'id': '549096',
#    'minute': '45',
#    'result': 'Goal',
#    'X': '0.93',
#    'Y': '0.5120000076293946',
#    'xG': '0.36938539147377014',
#    'player': 'Manuel Akanji',
#    'h_a': 'a',
#    'player_id': '6490',
#    'situation': 'FromCorner',
#    'season': '2023',
#    'shotType': 'Head',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': 'Bernardo Silva',
#    'lastAction': 'Cross'},
#   {'id': '549098',
#    'minute': '46',
#    'result': 'Goal',
#    'X': '0.9769999694824218',
#    'Y': '0.5279999923706055',
#    'xG': '0.8636682629585266',
#    'player': 'Erling Haaland',
#    'h_a': 'a',
#    'player_id': '8260',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'OtherBodyPart',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '549099',
#    'minute': '51',
#    'result': 'SavedShot',
#    'X': '0.86',
#    'Y': '0.49700000762939456',
#    'xG': '0.08055125176906586',
#    'player': 'Julián Álvarez',
#    'h_a': 'a',
#    'player_id': '10846',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': 'Rodri',
#    'lastAction': 'HeadPass'},
#   {'id': '549100',
#    'minute': '57',
#    'result': 'SavedShot',
#    'X': '0.8780000305175781',
#    'Y': '0.6359999847412109',
#    'xG': '0.10338891297578812',
#    'player': 'Jéremy Doku',
#    'h_a': 'a',
#    'player_id': '8981',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': 'Erling Haaland',
#    'lastAction': 'Pass'},
#   {'id': '549102',
#    'minute': '60',
#    'result': 'SavedShot',
#    'X': '0.8540000152587891',
#    'Y': '0.38599998474121094',
#    'xG': '0.08646918088197708',
#    'player': 'Phil Foden',
#    'h_a': 'a',
#    'player_id': '6055',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'LeftFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': 'Jack Grealish',
#    'lastAction': 'Pass'},
#   {'id': '549107',
#    'minute': '85',
#    'result': 'BlockedShot',
#    'X': '0.8059999847412109',
#    'Y': '0.495',
#    'xG': '0.04757215082645416',
#    'player': 'Mateo Kovacic',
#    'h_a': 'a',
#    'player_id': '2254',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': 'Erling Haaland',
#    'lastAction': 'Pass'},
#   {'id': '549108',
#    'minute': '85',
#    'result': 'Goal',
#    'X': '0.7669999694824219',
#    'Y': '0.5079999923706054',
#    'xG': '0.021162554621696472',
#    'player': 'Rodri',
#    'h_a': 'a',
#    'player_id': '2496',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'LeftFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': 'Erling Haaland',
#    'lastAction': 'Rebound'},
#   {'id': '549110',
#    'minute': '98',
#    'result': 'MissedShots',
#    'X': '0.749000015258789',
#    'Y': '0.5520000076293945',
#    'xG': '0.06224990636110306',
#    'player': 'Kyle Walker',
#    'h_a': 'a',
#    'player_id': '638',
#    'situation': 'DirectFreekick',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22009',
#    'h_team': 'Chelsea',
#    'a_team': 'Manchester City',
#    'h_goals': '4',
#    'a_goals': '4',
#    'date': '2023-11-12 16:30:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'}]}

# %%
# match_dic = {}
# def create_match_dic(row):
#     match_dic[(row['date'], row['h_team'], row['a_team'])] = match_dic.get((row['date'], row['h_team'], row['a_team']),[]) + [row]

# shotdf.apply( func = create_match_dic, axis=0)

# print(shotdf.head(10))

# print(list(match_dic.values())[:10])
# for val in match_dic.values():
#     val.sort(key = lambda row : row['minute'])

# %%
(shotdf[shotdf['date']=='2019-08-24 15:00:00'] ).sort_values(by=['h_team','minute']).to_csv('this_date.csv')
